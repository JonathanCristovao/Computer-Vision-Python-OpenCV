# %% [markdown]
# # <font color='blue'> Visão computacional com python & OpenCV </font>
# # <font color='black'> Capítulo 1- Canais RGB ( Red,Green e Blue) </font>

# %% [markdown]
# Download: https://github.com/JonathanCristovao/Computer-Vision-Python-OpenCV

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt
print(cv2.__version__)
print(np.__version__)
# Out:
# 4.5.1
# 1.19.2

# %%
#convertemos a imagem de BGR para RGB
imagem = cv2.cvtColor(imagem,cv2.COLOR_BGR2RGB)
plt.imshow(imagem)
plt.show()

# %% [markdown]
# Separando os canais RGB (Red,Green e Blue)

# %%
# lendo a imagem 
imagem = cv2.imread('superpoderosas.jpg')

plt.imshow(imagem)
plt.show() 
#observacao imagem com os canais
# "cv2.imread" faza leitura dos canais invertidos BGR e não RGB!

# %% [markdown]
# # Fim
